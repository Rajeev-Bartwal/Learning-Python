# %% [markdown]
# syntax - set of rules / or correct arrangmet of words and symbols in code
# symetic - it is about what that code is supposed to do when it runs

# %%
print("Hello World")
## syntax errors in python 
## case senstivity  --   this is a single line comment

##python is case sensitive

name = "rajeev"
Name="bartwal"
print(name)
print(Name)
# Out:
# Hello World
# rajeev
# bartwal

# %% [markdown]
# ### indentation
#
# indentaion in python is used to define the stucture and hierachy of the code.Unlike many other programming lang. that use braces {} to define the block of code. python uses indentaion to determine the block of code
# Python uses indentation to define blocks of code. consistant use of (commonly 4) spaces or a tab is required.

# %%
## indentation
# Python uses indentation to define blocks of code. consistant use of (commonly 4) spaces or a tab is required.

num = 3

if num > 2:
  print('greater')
else :
  print('smaller')
# Out:
# greater

# %% [markdown]
# ### Line continuation
#  you can use (backslash \) for the line continuation means continue the statement in next line as well

# %%
# Line continuation

total = 1+2+3+4+5+ \
  6+7+8+9

print(total)
# Out:
# 45

# %% [markdown]
# ## multiple statement in single line

# %%
# multiple statement in single line
x=5;y=6;z=x+y

print(z)
# Out:
# 11

# %% [markdown]
# ### understand semantics in python
# variable assignment (aynamically adapt the datatype you dont have to give it explicitly)

# %%
age = 32 #python will understand the age is a integer
name = "Rajeev" #name is a string


#type inference
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %% [markdown]
# ### Type inference
# During runtime python allocate the type of variable means you can change the type of variable during the runtime

# %%
#type inference dynamic type
var = 10
print(type(var))
var = 'rajeev'
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>
