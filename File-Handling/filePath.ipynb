# %%
import os
cwd = os.getcwd()
print(f'current directory is : {cwd}')
# Out:
# current directory is : d:\Rajeev\Ai Learning\Python\File-Handling

# %%
# Create a new directory. 

new_direc = "package"
os.mkdir(new_direc)
print(f'new directory is created : {new_direc}')
# Out:
# new directory is created : package

# %%
## Listing all files and directories

items = os.listdir('.')

print(items)
# Out:
# ['demo.txt', 'destination.txt', 'example.bin', 'example.txt', 'fileoperations.ipynb', 'filePath.ipynb', 'package']

# %%
## Joining Paths imp.

dir_nmame = "folder"
file_name = "file.text"

full_path = os.path.join(dir_nmame , file_name)
print(full_path)
# Out:
# folder\file.text

# %%
dir_nmame = "folder"
file_name = "file.text"

full_path = os.path.join(os.getcwd() , dir_nmame , file_name)
print(full_path)
# Out:
# d:\Rajeev\Ai Learning\Python\File-Handling\folder\file.text

# %%
path = 'example1/txt' 
if os.path.exists(path):
  print(f'The Path {path} exists')
else : 
  print(f"path {path} doen't exists")
# Out:
# path example1/txt doen't exists

# %%
# Chhecking the path is a file or a directory.

path = 'example.txt' 
if os.path.exists(path):
  print(f'The Path {path} is a file')
elif os.path.isdir(path):
  print(f'The Path {path} is a directory')
else : 
  print(f"path {path} doen't exists")

# %%
# getting the absolute path

relative_path = "example.txt"

absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\Rajeev\Ai Learning\Python\File-Handling\example.txt
