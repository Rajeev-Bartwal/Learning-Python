# %% [markdown]
# ## Magic Methods
#
# magic methods in Python, also known as dunder methods(double underscore methods) , are special methods that start and end with double underscores. These methods enable you to define the behavior of ubjects forbuilt-in operations. such as airthematic operations, comprehensions and more

# %% [markdown]
# ### Magic Methods
#
# Magic methods are predefined methods in Python, that you can override to change the behavior of your objects. Some common magic methods include:

# %%
'''
 __init__: initialize a new instance of a class.
 __str__: returns a string representaion of an object.
 __repr__: returns an official string representation of an object
 __len__ : Returns the length of the object
 __getitem__ : Gets an item  from a container
 __setItem__ : Sets an Item in a container
 
'''

# %%
class Person:
  pass

p = Person()
dir(p)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
print(p)

## Basic dunder methods

class Person:

  def __init__(self , name ,age):
    self.name = name
    self.age = age

  def __str__(self):
    return f'{self.name} is {self.age} yeas old'

  def __repr__(self):
    return f"Person (name = {self.name}  , age = {self.age})"

person = Person('rajeev' , 23)
print(person)
print(repr(person))
# Out:
# ...
# rajeev is 23 yeas old
# Person (name = rajeev  , age = 23)
