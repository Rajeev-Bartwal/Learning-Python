# %% [markdown]
# ### Logging with multiple Loggers
#
# you can create multiple loggers for different parts of your applications

# %%
import logging

# Create a logger for module1

logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

# Create a logger for module2

logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

logging.basicConfig(
  level = logging.DEBUG,
  format='%(asctime)s-%(name)s-%(levelname)s- %(message)s',
  datefmt= '%y-%m-%d %H:%M:%S'
)

# %%
# Log messages with diff logger

logger1.debug("This is a debug message")
logger2.warning("this isa waring message")
logger2.error('this is a error message')
# Out:
# 26-09-24 16:20:21-module1-DEBUG- This is a debug message
# 26-09-24 16:20:21-module2-WARNING- this isa waring message
# 26-09-24 16:20:21-module2-ERROR- this is a error message
